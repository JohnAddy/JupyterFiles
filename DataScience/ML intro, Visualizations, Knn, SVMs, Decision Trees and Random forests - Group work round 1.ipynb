# %% [markdown]
# Here we will be discussing on the differences between different main ML branches, namely the supervised and unsupervised learning. We pretty much pass the reinforcement learning branch which would be the third main big branch in machine learning. Also we will familiarize ourselves with some Python tools for visualizing and examining data and for having projects better organized. The Machine learning algorithms we cover in this part are KNN classifier, Support Vector Machines (SVMs), Decision Trees and Random Forests for both regression and classification. Knn algorithm is covered by the teacher whereas other topics are discussed though group works as discussed at the first lecture where we covered course info, course requirements, group working and commenting and briefly covered practice work also.

# %% [markdown]
# Plotly is a library that allows you to create interactive plots that you can use in dashboards or websites (you can save them as html files or static images).
#
# ### Installation
#
# We will need to install plotty and cufflinks to calls plots directly off a pandas dataframe. These libraries are not currently available through __conda__ but are available through **pip**. Install the libraries at your command line/terminal using:
#
# !pip install plotly
# !pip install cufflinks
#
#
# ### Imports and Set-up ###

# %%
# !pip install plotly
# !pip install cufflinks
# !conda install -c anaconda seaborn -y
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\johna\RobotLab
#
#   added / updated specs:
#     - seaborn
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     icu-58.2                   |   vc14hc45fdbb_0        21.9 MB  anaconda
#     matplotlib-base-3.2.2      |   py36h64f37c6_0         7.1 MB  anaconda
#     pandas-1.1.3               |   py36ha925a31_0         9.4 MB  anaconda
#     scipy-1.5.2                |   py36h9439919_0        15.2 MB  anaconda
#     ------------------------------------------------------------
#                                            Total:        53.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   icu                anaconda/win-64::icu-58.2-vc14hc45fdbb_0
#   matplotlib         anaconda/win-64::matplotlib-3.2.2-0
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
from plotly.offline import iplot
import plotly as py
import plotly.tools as tls
import plotly.express as px

# %%
import cufflinks as cf

# %% [markdown]
# __Using Cufflinks and iplot()__
#
# * line
# * scatter
# * bar
# * box
# * spread
# * ratio
# * heatmap
# * surface
# * histogram
# * bubble

# %%
print(py.__version__)
# Out:
# 5.2.2

# %%
df = pd.DataFrame()
help(df.iplot)
# Out:
# Help on method _iplot in module cufflinks.plotlytools:
#
# _iplot(kind='scatter', data=None, layout=None, filename='', sharing=None, title='', xTitle='', yTitle='', zTitle='', theme=None, colors=None, colorscale=None, fill=False, width=None, dash='solid', mode='', interpolation='linear', symbol='circle', size=12, barmode='', sortbars=False, bargap=None, bargroupgap=None, bins=None, histnorm='', histfunc='count', orientation='v', boxpoints=False, annotations=None, keys=False, bestfit=False, bestfit_colors=None, mean=False, mean_colors=None, categories='', x='', y='', z='', text='', gridcolor=None, zerolinecolor=None, margin=None, labels=None, values=None, secondary_y='', secondary_y_title='', subplots=False, shape=None, error_x=None, error_y=None, error_type='data', locations=None, lon=None, lat=None, asFrame=False, asDates=False, asFigure=False, asImage=False, dimensions=None, asPlot=False, asUrl=False, online=None, **kwargs) method of pandas.core.frame.DataFrame instance
# ...

# %%
tls.embed('https://plot.ly/~cufflinks/8')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-9ac3f4d6208c> in <module>
# ----> 1 tls.embed('https://plot.ly/~cf/8')
#
# AttributeError: module 'plotly.tools' has no attribute 'embed'
